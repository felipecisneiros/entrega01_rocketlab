# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze
COMMENT "Camada bronze para dados brutos com metadados de ingestão";

# %%
from pyspark.sql.functions import current_timestamp

arquivos = ["customers", "geolocation", "order_items", "order_payments", 
           "order_reviews", "orders", "products", "sellers", 
           "product_category_name_translation"]

# %%
df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .load("/Volumes/workspace/default/olist_customers")

df.write.format("delta").saveAsTable("bronze.customers")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-8198634588404901>, line 6
#       1 df = spark.read \
#       2     .format("csv") \
#       3     .option("header", "true") \
#       4     .load("/Volumes/workspace/default/olist_customers")
# ----> 6 df.write.format("delta").saveAsTable("bronze.customers")
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/readwriter.py:737, in DataFrameWriter.saveAsTable(self, name, format, mode, partitionBy, **options)
#     735 self._write.table_name = name
#     736 self._write.table_save_method = "save_as_table"
# --> 737 _, _, ei = self._spark.client.execute_command(
#     738     self._write.command(self._spark.client), self._write.observations
#     739 )
#     740 self._callback(ei)
#
# ...

# %%
 df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .load("/Volumes/workspace/default/olist_geolocation")

df.write.format("delta").saveAsTable("bronze.geolocation")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-8198634588404902>, line 6
#       1 df = spark.read \
#       2     .format("csv") \
#       3     .option("header", "true") \
#       4     .load("/Volumes/workspace/default/olist_geolocation")
# ----> 6 df.write.format("delta").saveAsTable("bronze.geolocation")
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/readwriter.py:737, in DataFrameWriter.saveAsTable(self, name, format, mode, partitionBy, **options)
#     735 self._write.table_name = name
#     736 self._write.table_save_method = "save_as_table"
# --> 737 _, _, ei = self._spark.client.execute_command(
#     738     self._write.command(self._spark.client), self._write.observations
#     739 )
#     740 self._callback(ei)
#
# ...

# %%
df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .load("/Volumes/workspace/default/olist_order_items")

df.write.format("delta").saveAsTable("bronze.order_items")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-8198634588404903>, line 6
#       1 df = spark.read \
#       2     .format("csv") \
#       3     .option("header", "true") \
#       4     .load("/Volumes/workspace/default/olist_order_items")
# ----> 6 df.write.format("delta").saveAsTable("bronze.order_items")
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/readwriter.py:737, in DataFrameWriter.saveAsTable(self, name, format, mode, partitionBy, **options)
#     735 self._write.table_name = name
#     736 self._write.table_save_method = "save_as_table"
# --> 737 _, _, ei = self._spark.client.execute_command(
#     738     self._write.command(self._spark.client), self._write.observations
#     739 )
#     740 self._callback(ei)
#
# ...

# %%
df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .load("/Volumes/workspace/default/olist_order_payments")

df.write.format("delta").saveAsTable("bronze.order_payments")

# %%
df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .load("/Volumes/workspace/default/olist_order_reviews")

df.write.format("delta").saveAsTable("bronze.order_reviews")

# %%
df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .load("/Volumes/workspace/default/olist_orders")

df.write.format("delta").saveAsTable("bronze.orders")

# %%
df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .load("/Volumes/workspace/default/olist_products")

df.write.format("delta").saveAsTable("bronze.products")

# %%
df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .load("/Volumes/workspace/default/olist_sellers")

df.write.format("delta").saveAsTable("bronze.sellers")

# %%
df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .load("/Volumes/workspace/default/product_category_name_translation")

df.write.format("delta").saveAsTable("bronze.product_category_name_translation")
